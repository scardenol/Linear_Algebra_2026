# %% [markdown]
# <a href="https://colab.research.google.com/github/scardenol/Linear_Algebra_2026/blob/main/Taller%203/seudoinversa_descomposicion_valores_singulares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Inversa generalizada usando SVD
import numpy as np
from scipy import linalg
from IPython.display import display, Math
import sympy as sp

# %% [markdown]
# # 1) $A\mathbf{x}=\mathbf{b}$ punto (a)

# %%
# Definir la matriz
A = np.array([[5, 0], [0, 10]])

P, D, QT = linalg.svd(A)

k = len(D) #Da el número de componentes distintas de cero en D
Q = QT.T
PT = P.T
D = np.diag(D) #Construir una matriz cuadrada con diagonal D
Dinv = np.linalg.inv(D) #inversa de la matriz D

#Ajustar la dimensión de Q y PT para la multiplicación por Dinv
Q = Q[:, :k] #elimina todas las columnas de Q desde la k+1 hasta la última
PT = PT[:k, :] #elimina todas las filas de PT desde la k+1 hasta la última

Ainvg = Q@Dinv@PT # Cálculo manual de la inversa generalizada
Aplus = linalg.pinv(A) # Cálculo con el paquete de álgebra lineal scipy.linalg

display(Math(r"D = " + sp.latex(sp.Matrix(D))))
print("")
display(Math(r"Q = " + sp.latex(sp.Matrix(Q))))
print("")
display(Math(r"P^T = " + sp.latex(sp.Matrix(PT))))
print("")
display(Math(r"\Delta^+ = " + sp.latex(sp.Matrix(Dinv))))
print("")
display(Math(r"A_{\text{invg}} = " + sp.latex(sp.Matrix(Ainvg))))
print("")
display(Math(r"A_{\text{plus}} = " + sp.latex(sp.Matrix(Aplus))))
# Out:
# $\displaystyle D = \left[\begin{matrix}10.0 & 0.0\\0.0 & 5.0\end{matrix}\right]$
# $\displaystyle Q = \left[\begin{matrix}0.0 & 1.0\\1.0 & 0.0\end{matrix}\right]$
# $\displaystyle P^T = \left[\begin{matrix}0.0 & 1.0\\1.0 & 0.0\end{matrix}\right]$
# $\displaystyle \Delta^+ = \left[\begin{matrix}0.1 & 0.0\\0.0 & 0.2\end{matrix}\right]$
# $\displaystyle A_{\text{invg}} = \left[\begin{matrix}0.2 & 0.0\\0.0 & 0.1\end{matrix}\right]$
# $\displaystyle A_{\text{plus}} = \left[\begin{matrix}0.2 & 0.0\\0.0 & 0.1\end{matrix}\right]$
